# %% [markdown]
# ### Getting Steam App IDs and Information
#
# This notebook is dedicated towards collecting a list of all available games on Steam. It uses a public API provided by SteamWorks and sends a GET request, which returns a list of all steam games by ID. It will also download information about games using their app ID and another API. First, import the necessary packages for this code. Running this notebook will begin to download information about all games on Steam to your computer in the same directory. They will be serialized into a pickle object for storage.

# %%
from collections import deque
from datetime import datetime
import os
import time
import requests
import json

import pickle
from pathlib import Path

import traceback

# %% [markdown]
# Next, several methods are defined to process and retrieve the data. The following method retrieves data from Steam's database, returning a list of all games and the associated app ID.

# %%
def get_app_ids():
    
    req = requests.get("https://api.steampowered.com/ISteamApps/GetAppList/v2/")

    if (req.status_code != 200):
        print_log("Failed to get all games on steam.")
        return
    
    try:
        data = req.json()
    except Exception as e:
        traceback.print_exc(limit=5)
        return {}
    
    apps_data = data['applist']['apps']

    apps_ids = []

    for app in apps_data:
        appid = app['appid']
        name = app['name']
        
        # skip apps that have empty name
        if not name:
            continue

        apps_ids.append(appid)

    return apps_ids

# %% [markdown]
# Using these app IDs, we can start requesting detailed information about each game on Steam. Unfortunately, there is a limit of about 200 requests per minutes, and with over 200,000 games on steam, it would take about 3 or 4 days to download all the possible data. In order to avoid having to restart from the beginning or downloading repeat data should the program be closed suddenly, safeguards have been added to provide a checkpoint for data download. This notebook may need to be periodically checked and restarted from time to time to properly download all data.

# %%
def print_log(*args):
    print(f"[{str(datetime.now())[:-3]}] ", end="")
    print(*args)

def save_checkpoints(checkpoint_folder, apps_dict_filename_prefix, exc_apps_filename_prefix, error_apps_filename_prefix, apps_dict, excluded_apps_list, error_apps_list):
    if not checkpoint_folder.exists():
        checkpoint_folder.mkdir(parents=True)

    save_path = checkpoint_folder.joinpath(
        apps_dict_filename_prefix + f'-ckpt-fin.p'
    ).resolve()

    save_path2 = checkpoint_folder.joinpath(
        exc_apps_filename_prefix + f'-ckpt-fin.p'
    ).resolve()
    
    save_path3 = checkpoint_folder.joinpath(
        error_apps_filename_prefix + f'-ckpt-fin.p'
    ).resolve()

    save_pickle(save_path, apps_dict)
    print_log(f'Successfully create app_dict checkpoint: {save_path}')

    save_pickle(save_path2, excluded_apps_list)
    print_log(f"Successfully create excluded apps checkpoint: {save_path2}")

    save_pickle(save_path3, error_apps_list)
    print_log(f"Successfully create error apps checkpoint: {save_path3}")

    print()


def load_pickle(path_to_load:Path) -> dict:
    obj = pickle.load(open(path_to_load, "rb"))
    
    return obj

def save_pickle(path_to_save:Path, obj):
    with open(path_to_save, 'wb') as handle:
        pickle.dump(obj, handle, protocol=pickle.HIGHEST_PROTOCOL)

def check_latest_checkpoints(checkpoint_folder, apps_dict_filename_prefix, exc_apps_filename_prefix, error_apps_filename_prefix):
    # app_dict
    all_pkl = []

    # get all pickle files in the checkpoint folder    
    for root, dirs, files in os.walk(checkpoint_folder):
        all_pkl = list(map(lambda f: Path(root, f), files))
        all_pkl = [p for p in all_pkl if p.suffix == '.p']
        break
            
    # create a list to store all the checkpoint files
    # then sort them
    # the latest checkpoint file for each of the object is the last element in each of the lists
    apps_dict_ckpt_files = [f for f in all_pkl if apps_dict_filename_prefix in f.name and "ckpt" in f.name]
    exc_apps_list_ckpt_files = [f for f in all_pkl if exc_apps_filename_prefix in f.name and "ckpt" in f.name]
    error_apps_ckpt_files = [f for f in all_pkl if error_apps_filename_prefix in f.name and 'ckpt' in f.name]

    apps_dict_ckpt_files.sort()
    exc_apps_list_ckpt_files.sort()
    error_apps_ckpt_files.sort()

    latest_apps_dict_ckpt_path = apps_dict_ckpt_files[-1] if apps_dict_ckpt_files else None
    latest_exc_apps_list_ckpt_path = exc_apps_list_ckpt_files[-1] if exc_apps_list_ckpt_files else None
    latest_error_apps_list_ckpt_path = error_apps_ckpt_files[-1] if error_apps_ckpt_files else None

    return latest_apps_dict_ckpt_path, latest_exc_apps_list_ckpt_path, latest_error_apps_list_ckpt_path

# %% [markdown]
# Finally, we can write a function that retrieves all of the IDs, the information associated with each game, and stores them in a readable format that we can use to scrape information from.

# %%
def main():
    print_log("Started Steam scraper process", os.getpid())


    apps_dict_filename_prefix = 'apps_dict'
    exc_apps_filename_prefix = 'excluded_apps_list'
    error_apps_filename_prefix = 'error_apps_list'

    apps_dict = {}
    excluded_apps_list = []
    error_apps_list = []

    all_app_ids = get_app_ids()

    print_log('Total number of apps on steam:', len(all_app_ids))

    # path = project directory (i.e. steam_data_scraping)/checkpoints
    checkpoint_folder = Path('../checkpoints').resolve()

    print_log('Checkpoint folder:', checkpoint_folder)

    if not checkpoint_folder.exists():
        print_log(f'Fail to find checkpoint folder: {checkpoint_folder}')
        print_log(f'Start at blank.')

        checkpoint_folder.mkdir(parents=True)

    latest_apps_dict_ckpt_path, latest_exc_apps_list_ckpt_path, latest_error_apps_list_ckpt_path = check_latest_checkpoints(checkpoint_folder, apps_dict_filename_prefix, exc_apps_filename_prefix, error_apps_filename_prefix)

    if latest_apps_dict_ckpt_path:
        apps_dict = load_pickle(latest_apps_dict_ckpt_path)
        print_log('Successfully load apps_dict checkpoint:', latest_apps_dict_ckpt_path)
        print_log(f'Number of apps in apps_dict: {len(apps_dict)}')
    
    if latest_exc_apps_list_ckpt_path:
        excluded_apps_list = load_pickle(latest_exc_apps_list_ckpt_path)
        print_log("Successfully load excluded_apps_list checkpoint:", latest_exc_apps_list_ckpt_path)
        print_log(f'Number of apps in excluded_apps_list: {len(excluded_apps_list)}')

    if latest_error_apps_list_ckpt_path:
        error_apps_list = load_pickle(latest_error_apps_list_ckpt_path)
        print_log("Successfully load error_apps_list checkpoint:", latest_error_apps_list_ckpt_path)
        print_log(f'Number of apps in error_apps_list: {len(error_apps_list)}')

    # remove app_ids that already scrapped or excluded or error
    all_app_ids = set(all_app_ids) \
            - set(map(int, set(apps_dict.keys()))) \
            - set(map(int, excluded_apps_list)) \
            - set(map(int, error_apps_list))
        
    # first get remaining apps
    apps_remaining_deque = deque(set(all_app_ids))

    
    print('Number of remaining apps:', len(apps_remaining_deque))

    i = 0
    while len(apps_remaining_deque) > 0:
        appid = apps_remaining_deque.popleft()

        # test whether the game exists or not
        # by making request to get the details of the app
        try:
            appdetails_req = requests.get(f"https://store.steampowered.com/api/appdetails?appids={appid}")

            if appdetails_req.status_code == 200:
                appdetails = appdetails_req.json()
                appdetails = appdetails[str(appid)]

            elif appdetails_req.status_code == 429:
                print_log(f'Too many requests. Put App ID {appid} back to deque. Sleep for 10 sec')
                apps_remaining_deque.appendleft(appid)
                time.sleep(10)
                continue


            elif appdetails_req.status_code == 403:
                print_log(f'Forbidden to access. Put App ID {appid} back to deque. Sleep for 5 min.')
                apps_remaining_deque.appendleft(appid)
                time.sleep(5 * 60)
                continue

            else:
                print_log("ERROR: status code:", appdetails_req.status_code)
                print_log(f"Error in App Id: {appid}. Put the app to error apps list.")
                error_apps_list.append(appid)
                continue
                
        except:
            print_log(f"Error in decoding app details request. App id: {appid}")

            traceback.print_exc(limit=5)
            appdetails = {'success':False}
            print()

        # not success -> the game does not exist anymore
        # add the app id to excluded app id list
        if appdetails['success'] == False:
            excluded_apps_list.append(appid)
            print_log(f'No successful response. Add App ID: {appid} to excluded apps list')
            continue

        appdetails_data = appdetails['data']

        appdetails_data['appid'] = appid     

        apps_dict[appid] = appdetails_data
        print_log(f"Successfully get content of App ID: {appid}")

        i += 1
        # for each 2500, save a ckpt
        if i >= 2500:
            save_checkpoints(checkpoint_folder, apps_dict_filename_prefix, exc_apps_filename_prefix, error_apps_filename_prefix, apps_dict, excluded_apps_list, error_apps_list)
            i = 0

    # save checkpoints at the end
    save_checkpoints(checkpoint_folder, apps_dict_filename_prefix, exc_apps_filename_prefix, error_apps_filename_prefix, apps_dict, excluded_apps_list, error_apps_list)

    print_log(f"Total number of valid apps: {len(apps_dict)}")
    print_log(f"Total number of skipped apps: {len(excluded_apps_list)}")
    print_log(f"Total number of error apps: {len(error_apps_list)}")

    print_log('Successful run. Program Terminates.')

# %%
main()
# Out:
# [2025-05-03 21:21:30.962] Started Steam scraper process 25080
# [2025-05-03 21:21:32.094] Total number of apps on steam: 245070
# [2025-05-03 21:21:32.094] Checkpoint folder: C:\Users\azure\Documents\CS122\project\checkpoints
# [2025-05-03 21:21:39.817] Successfully load apps_dict checkpoint: C:\Users\azure\Documents\CS122\project\checkpoints\apps_dict-ckpt-fin.p
# [2025-05-03 21:21:39.817] Number of apps in apps_dict: 123992
# [2025-05-03 21:21:39.819] Successfully load excluded_apps_list checkpoint: C:\Users\azure\Documents\CS122\project\checkpoints\excluded_apps_list-ckpt-fin.p
# [2025-05-03 21:21:39.819] Number of apps in excluded_apps_list: 113626
# [2025-05-03 21:21:39.820] Successfully load error_apps_list checkpoint: C:\Users\azure\Documents\CS122\project\checkpoints\error_apps_list-ckpt-fin.p
# [2025-05-03 21:21:39.820] Number of apps in error_apps_list: 145
# Number of remaining apps: 2893
# [2025-05-03 21:21:40.186] Successfully get content of App ID: 1499140
# [2025-05-03 21:21:40.415] Successfully get content of App ID: 1499150
# [2025-05-03 21:21:40.749] Successfully get content of App ID: 1499160
# [2025-05-03 21:21:41.047] Successfully get content of App ID: 1499170
# [2025-05-03 21:21:41.423] Successfully get content of App ID: 2244650
# [2025-05-03 21:21:41.672] Successfully get content of App ID: 1499180
# [2025-05-03 21:21:41.949] Successfully get content of App ID: 2220080
# [2025-05-03 21:21:42.202] Successfully get content of App ID: 1499190
# [2025-05-03 21:21:42.448] Successfully get content of App ID: 3686460
# [2025-05-03 21:21:42.770] Successfully get content of App ID: 1499210
# [2025-05-03 21:21:43.035] Successfully get content of App ID: 1499220
# [2025-05-03 21:21:43.287] Successfully get content of App ID: 1499230
# [2025-05-03 21:21:43.631] Successfully get content of App ID: 1499240
# [2025-05-03 21:21:44.010] Successfully get content of App ID: 1564790
# [2025-05-03 21:21:44.304] Successfully get content of App ID: 3268730
# [2025-05-03 21:21:44.580] Successfully get content of App ID: 3268740
# [2025-05-03 21:21:44.817] Successfully get content of App ID: 1499270
# [2025-05-03 21:21:45.210] Successfully get content of App ID: 909450
# [2025-05-03 21:21:45.938] No successful response. Add App ID: 3268750 to excluded apps list
# [2025-05-03 21:21:46.242] Successfully get content of App ID: 1499280
# [2025-05-03 21:21:46.483] Successfully get content of App ID: 909460
# [2025-05-03 21:21:46.706] Successfully get content of App ID: 1499290
# [2025-05-03 21:21:46.958] Successfully get content of App ID: 1564830
# [2025-05-03 21:21:47.213] Successfully get content of App ID: 1499300
# [2025-05-03 21:21:47.477] Successfully get content of App ID: 909480
# [2025-05-03 21:21:47.740] Successfully get content of App ID: 1564840
# [2025-05-03 21:21:47.981] Successfully get content of App ID: 1499310
# [2025-05-03 21:21:48.249] No successful response. Add App ID: 3268790 to excluded apps list
# [2025-05-03 21:21:48.512] Successfully get content of App ID: 1499320
# [2025-05-03 21:21:48.834] Successfully get content of App ID: 909500
# [2025-05-03 21:21:49.110] Successfully get content of App ID: 3268800
# [2025-05-03 21:21:49.473] Successfully get content of App ID: 1499330
# [2025-05-03 21:21:49.818] Successfully get content of App ID: 1564870
# [2025-05-03 21:21:50.110] No successful response. Add App ID: 3268810 to excluded apps list
# [2025-05-03 21:21:50.379] Successfully get content of App ID: 1499340
# [2025-05-03 21:21:50.637] Successfully get content of App ID: 1499350
# [2025-05-03 21:21:51.124] Successfully get content of App ID: 909530
# [2025-05-03 21:21:51.382] Successfully get content of App ID: 1499360
# [2025-05-03 21:21:51.677] Successfully get content of App ID: 1564900
# [2025-05-03 21:21:51.942] Successfully get content of App ID: 1499370
# [2025-05-03 21:21:52.189] Successfully get content of App ID: 909550
# [2025-05-03 21:21:52.416] Successfully get content of App ID: 1564910
# [2025-05-03 21:21:52.726] Successfully get content of App ID: 1499380
# [2025-05-03 21:21:53.073] Successfully get content of App ID: 1564920
# [2025-05-03 21:21:53.292] Successfully get content of App ID: 1499390
# [2025-05-03 21:21:53.642] Successfully get content of App ID: 909570
# [2025-05-03 21:21:54.042] Successfully get content of App ID: 1564930
# [2025-05-03 21:21:54.318] Successfully get content of App ID: 3268870
# [2025-05-03 21:21:54.562] Successfully get content of App ID: 909580
# [2025-05-03 21:21:54.897] Successfully get content of App ID: 1564940
# [2025-05-03 21:21:55.152] No successful response. Add App ID: 3268880 to excluded apps list
# [2025-05-03 21:21:55.374] Successfully get content of App ID: 1499410
# [2025-05-03 21:21:55.635] No successful response. Add App ID: 1501277 to excluded apps list
# [2025-05-03 21:21:55.928] Successfully get content of App ID: 909590
# [2025-05-03 21:21:56.190] Successfully get content of App ID: 1564950
# [2025-05-03 21:21:56.475] No successful response. Add App ID: 1501278 to excluded apps list
# [2025-05-03 21:21:56.747] Successfully get content of App ID: 1499420
# [2025-05-03 21:21:56.964] Successfully get content of App ID: 909600
# [2025-05-03 21:21:57.267] Successfully get content of App ID: 3268900
# [2025-05-03 21:21:57.504] Successfully get content of App ID: 1499430
# [2025-05-03 21:21:57.850] Successfully get content of App ID: 909610
# [2025-05-03 21:21:58.138] Successfully get content of App ID: 1564970
# [2025-05-03 21:21:58.412] Successfully get content of App ID: 3268910
# [2025-05-03 21:21:58.694] Successfully get content of App ID: 1499440
# [2025-05-03 21:21:58.916] Successfully get content of App ID: 1564980
# [2025-05-03 21:21:59.172] No successful response. Add App ID: 3268920 to excluded apps list
# [2025-05-03 21:21:59.448] Successfully get content of App ID: 1499450
# [2025-05-03 21:21:59.697] Successfully get content of App ID: 909630
# [2025-05-03 21:21:59.993] Successfully get content of App ID: 1564990
# [2025-05-03 21:22:00.248] Successfully get content of App ID: 3268930
# [2025-05-03 21:22:00.514] Successfully get content of App ID: 1499460
# [2025-05-03 21:22:00.809] Successfully get content of App ID: 909640
# [2025-05-03 21:22:01.140] Successfully get content of App ID: 1499470
# [2025-05-03 21:22:01.405] Successfully get content of App ID: 909650
# [2025-05-03 21:22:01.980] Successfully get content of App ID: 1565020
# [2025-05-03 21:22:02.243] Successfully get content of App ID: 1499490
# [2025-05-03 21:22:02.465] Successfully get content of App ID: 909670
# [2025-05-03 21:22:02.695] Successfully get content of App ID: 1565030
# [2025-05-03 21:22:02.976] Successfully get content of App ID: 3268970
# [2025-05-03 21:22:03.194] Successfully get content of App ID: 1499500
# [2025-05-03 21:22:03.476] Successfully get content of App ID: 3268980
# [2025-05-03 21:22:03.744] Successfully get content of App ID: 1499510
# [2025-05-03 21:22:03.998] Successfully get content of App ID: 909690
# [2025-05-03 21:22:04.279] Successfully get content of App ID: 3268990
# [2025-05-03 21:22:04.530] Successfully get content of App ID: 1499520
# [2025-05-03 21:22:04.833] Successfully get content of App ID: 1565060
# [2025-05-03 21:22:05.057] No successful response. Add App ID: 3269000 to excluded apps list
# [2025-05-03 21:22:05.268] Successfully get content of App ID: 909710
# [2025-05-03 21:22:05.529] Successfully get content of App ID: 1565070
# [2025-05-03 21:22:05.946] Successfully get content of App ID: 3269010
# [2025-05-03 21:22:06.225] Successfully get content of App ID: 1499540
# [2025-05-03 21:22:06.615] Successfully get content of App ID: 909720
# [2025-05-03 21:22:07.002] Successfully get content of App ID: 1565080
# [2025-05-03 21:22:07.264] Successfully get content of App ID: 1499550
# [2025-05-03 21:22:07.494] Successfully get content of App ID: 909730
# [2025-05-03 21:22:07.743] Successfully get content of App ID: 1565090
# [2025-05-03 21:22:08.034] No successful response. Add App ID: 1499560 to excluded apps list
# [2025-05-03 21:22:08.263] Successfully get content of App ID: 909750
# [2025-05-03 21:22:08.503] Successfully get content of App ID: 1565110
# [2025-05-03 21:22:08.724] Successfully get content of App ID: 3269050
# [2025-05-03 21:22:09.004] No successful response. Add App ID: 3269060 to excluded apps list
# [2025-05-03 21:22:09.274] Successfully get content of App ID: 1499590
# [2025-05-03 21:22:09.504] Successfully get content of App ID: 1565130
# [2025-05-03 21:22:09.722] Successfully get content of App ID: 3269070
# [2025-05-03 21:22:09.967] No successful response. Add App ID: 1499600 to excluded apps list
# [2025-05-03 21:22:10.217] Successfully get content of App ID: 3269080
# [2025-05-03 21:22:10.487] Successfully get content of App ID: 1565150
# [2025-05-03 21:22:10.740] Successfully get content of App ID: 3269090
# [2025-05-03 21:22:11.018] Successfully get content of App ID: 1565160
# [2025-05-03 21:22:11.245] Successfully get content of App ID: 3269100
# [2025-05-03 21:22:11.480] Successfully get content of App ID: 1565170
# [2025-05-03 21:22:11.746] Successfully get content of App ID: 1499640
# [2025-05-03 21:22:12.015] Successfully get content of App ID: 909820
# [2025-05-03 21:22:12.290] Successfully get content of App ID: 1565180
# [2025-05-03 21:22:12.513] Successfully get content of App ID: 3269120
# [2025-05-03 21:22:12.767] Successfully get content of App ID: 1499650
# [2025-05-03 21:22:13.066] Successfully get content of App ID: 909830
# [2025-05-03 21:22:13.341] No successful response. Add App ID: 1565190 to excluded apps list
# [2025-05-03 21:22:13.616] Successfully get content of App ID: 1499660
# [2025-05-03 21:22:14.010] Successfully get content of App ID: 3695120
# [2025-05-03 21:22:14.315] Successfully get content of App ID: 1565200
# [2025-05-03 21:22:15.642] No successful response. Add App ID: 3269140 to excluded apps list
# [2025-05-03 21:22:15.939] Successfully get content of App ID: 1499670
# [2025-05-03 21:22:16.203] Successfully get content of App ID: 909850
# [2025-05-03 21:22:16.682] Successfully get content of App ID: 909851
# [2025-05-03 21:22:17.000] Successfully get content of App ID: 1565210
# [2025-05-03 21:22:17.284] Successfully get content of App ID: 3269150
# [2025-05-03 21:22:17.566] Successfully get content of App ID: 1499680
# [2025-05-03 21:22:17.779] Successfully get content of App ID: 3695140
# [2025-05-03 21:22:18.133] Successfully get content of App ID: 1565220
# [2025-05-03 21:22:18.388] Successfully get content of App ID: 3269160
# [2025-05-03 21:22:18.693] Successfully get content of App ID: 1499690
# [2025-05-03 21:22:19.014] Successfully get content of App ID: 909870
# [2025-05-03 21:22:19.284] Successfully get content of App ID: 1565240
# [2025-05-03 21:22:19.595] Successfully get content of App ID: 1499710
# [2025-05-03 21:22:19.867] Successfully get content of App ID: 1565250
# [2025-05-03 21:22:20.107] Successfully get content of App ID: 3269190
# [2025-05-03 21:22:20.617] Successfully get content of App ID: 1499720
# [2025-05-03 21:22:21.713] Successfully get content of App ID: 909900
# [2025-05-03 21:22:22.061] Successfully get content of App ID: 1565270
# [2025-05-03 21:22:22.323] Successfully get content of App ID: 3269210
# [2025-05-03 21:22:22.586] Successfully get content of App ID: 3269220
# [2025-05-03 21:22:22.868] Successfully get content of App ID: 1499750
# [2025-05-03 21:22:23.221] Successfully get content of App ID: 1565290
# [2025-05-03 21:22:23.516] Successfully get content of App ID: 1499760
# [2025-05-03 21:22:23.826] Successfully get content of App ID: 3613300
# [2025-05-03 21:22:24.157] Successfully get content of App ID: 1565300
# [2025-05-03 21:22:24.430] Successfully get content of App ID: 3269240
# [2025-05-03 21:22:24.688] Successfully get content of App ID: 1499770
# [2025-05-03 21:22:24.964] Successfully get content of App ID: 3269250
# [2025-05-03 21:22:25.204] Successfully get content of App ID: 1499780
# [2025-05-03 21:22:25.474] Successfully get content of App ID: 3695240
# [2025-05-03 21:22:25.735] Successfully get content of App ID: 1565320
# [2025-05-03 21:22:25.941] Successfully get content of App ID: 1499790
# [2025-05-03 21:22:26.155] Successfully get content of App ID: 3695250
# [2025-05-03 21:22:26.424] Successfully get content of App ID: 909970
# [2025-05-03 21:22:26.680] Successfully get content of App ID: 1499800
# [2025-05-03 21:22:26.933] Successfully get content of App ID: 1499820
# [2025-05-03 21:22:27.268] Successfully get content of App ID: 3269300
# [2025-05-03 21:22:27.498] Successfully get content of App ID: 2286260
# [2025-05-03 21:22:27.725] Successfully get content of App ID: 1499830
# [2025-05-03 21:22:28.016] Successfully get content of App ID: 3269310
# [2025-05-03 21:22:28.281] Successfully get content of App ID: 3269330
# [2025-05-03 21:22:28.550] Successfully get content of App ID: 910040
# [2025-05-03 21:22:28.804] Successfully get content of App ID: 3269340
# [2025-05-03 21:22:29.052] Successfully get content of App ID: 910050
# [2025-05-03 21:22:29.340] Successfully get content of App ID: 1565410
# [2025-05-03 21:22:29.626] Successfully get content of App ID: 1565411
# [2025-05-03 21:22:29.891] Successfully get content of App ID: 1565412
# [2025-05-03 21:22:30.137] Successfully get content of App ID: 3269350
# [2025-05-03 21:22:30.365] Successfully get content of App ID: 1565413
# [2025-05-03 21:22:30.615] Successfully get content of App ID: 1499880
# [2025-05-03 21:22:30.900] Successfully get content of App ID: 1565415
# [2025-05-03 21:22:31.236] Successfully get content of App ID: 3703530
# [2025-05-03 21:22:31.457] Successfully get content of App ID: 1565420
# [2025-05-03 21:22:31.836] Successfully get content of App ID: 3269360
# [2025-05-03 21:22:32.209] Successfully get content of App ID: 1499890
# [2025-05-03 21:22:32.496] Successfully get content of App ID: 1565430
# [2025-05-03 21:22:32.752] Successfully get content of App ID: 3269370
# [2025-05-03 21:22:33.005] Successfully get content of App ID: 1499900
# [2025-05-03 21:22:33.257] Successfully get content of App ID: 1565440
# [2025-05-03 21:22:33.555] Successfully get content of App ID: 1499910
# [2025-05-03 21:22:33.780] Successfully get content of App ID: 1565450
# [2025-05-03 21:22:34.071] Successfully get content of App ID: 3269390
# [2025-05-03 21:22:34.385] Successfully get content of App ID: 1565460
# [2025-05-03 21:22:34.646] Successfully get content of App ID: 1499930
# [2025-05-03 21:22:34.882] Successfully get content of App ID: 3269410
# [2025-05-03 21:22:35.143] Successfully get content of App ID: 1499940
# [2025-05-03 21:22:35.421] Successfully get content of App ID: 1499960
# [2025-05-03 21:22:35.731] Successfully get content of App ID: 1565500
# [2025-05-03 21:22:35.976] Successfully get content of App ID: 3269440
# [2025-05-03 21:22:36.274] Successfully get content of App ID: 910150
# [2025-05-03 21:22:36.670] Successfully get content of App ID: 3269450
# [2025-05-03 21:22:37.863] Successfully get content of App ID: 1499980
# [2025-05-03 21:22:38.092] Successfully get content of App ID: 910160
# [2025-05-03 21:22:38.414] Successfully get content of App ID: 1565520
# [2025-05-03 21:22:38.695] Successfully get content of App ID: 3269460
# [2025-05-03 21:22:38.997] Successfully get content of App ID: 1499990
# [2025-05-03 21:22:39.894] Successfully get content of App ID: 1565530
# [2025-05-03 21:22:40.196] Successfully get content of App ID: 910180
# [2025-05-03 21:22:40.459] Successfully get content of App ID: 3269480
# [2025-05-03 21:22:40.857] Too many requests. Put App ID 910190 back to deque. Sleep for 10 sec
# [2025-05-03 21:22:51.132] Too many requests. Put App ID 910190 back to deque. Sleep for 10 sec
# [2025-05-03 21:23:01.424] Too many requests. Put App ID 910190 back to deque. Sleep for 10 sec
# [2025-05-03 21:23:11.682] Too many requests. Put App ID 910190 back to deque. Sleep for 10 sec
# [2025-05-03 21:23:21.884] Too many requests. Put App ID 910190 back to deque. Sleep for 10 sec
# [2025-05-03 21:23:32.219] Too many requests. Put App ID 910190 back to deque. Sleep for 10 sec
# [2025-05-03 21:23:42.439] Too many requests. Put App ID 910190 back to deque. Sleep for 10 sec
# [2025-05-03 21:23:52.764] Too many requests. Put App ID 910190 back to deque. Sleep for 10 sec
# [2025-05-03 21:24:03.053] Too many requests. Put App ID 910190 back to deque. Sleep for 10 sec
# [2025-05-03 21:24:13.341] Too many requests. Put App ID 910190 back to deque. Sleep for 10 sec
# [2025-05-03 21:24:23.557] Too many requests. Put App ID 910190 back to deque. Sleep for 10 sec
# [2025-05-03 21:24:34.395] Too many requests. Put App ID 910190 back to deque. Sleep for 10 sec
# [2025-05-03 21:24:44.854] Too many requests. Put App ID 910190 back to deque. Sleep for 10 sec
# [2025-05-03 21:24:55.179] Too many requests. Put App ID 910190 back to deque. Sleep for 10 sec
# [2025-05-03 21:25:05.504] Too many requests. Put App ID 910190 back to deque. Sleep for 10 sec
# [2025-05-03 21:25:16.455] Too many requests. Put App ID 910190 back to deque. Sleep for 10 sec
# [2025-05-03 21:25:26.686] Too many requests. Put App ID 910190 back to deque. Sleep for 10 sec
# [2025-05-03 21:25:37.065] Too many requests. Put App ID 910190 back to deque. Sleep for 10 sec
# [2025-05-03 21:25:47.306] Too many requests. Put App ID 910190 back to deque. Sleep for 10 sec
# [2025-05-03 21:25:57.598] Too many requests. Put App ID 910190 back to deque. Sleep for 10 sec
# [2025-05-03 21:26:07.837] Too many requests. Put App ID 910190 back to deque. Sleep for 10 sec
# [2025-05-03 21:26:18.112] Too many requests. Put App ID 910190 back to deque. Sleep for 10 sec
# [2025-05-03 21:26:28.407] Too many requests. Put App ID 910190 back to deque. Sleep for 10 sec
# [2025-05-03 21:26:38.686] Too many requests. Put App ID 910190 back to deque. Sleep for 10 sec
# [2025-05-03 21:26:48.955] Successfully get content of App ID: 910190
# [2025-05-03 21:26:49.251] No successful response. Add App ID: 3269490 to excluded apps list
# [2025-05-03 21:26:49.508] Successfully get content of App ID: 910200
# [2025-05-03 21:26:49.778] Successfully get content of App ID: 1565560
# [2025-05-03 21:26:50.093] Successfully get content of App ID: 1500030
# [2025-05-03 21:26:50.647] Successfully get content of App ID: 910210
# [2025-05-03 21:26:52.536] Successfully get content of App ID: 3269510
# [2025-05-03 21:26:52.820] Successfully get content of App ID: 1500040
# [2025-05-03 21:26:53.053] Successfully get content of App ID: 910220
# [2025-05-03 21:26:53.476] Successfully get content of App ID: 1565580
# [2025-05-03 21:26:53.781] Successfully get content of App ID: 910230
# [2025-05-03 21:26:54.073] Successfully get content of App ID: 3269530
# [2025-05-03 21:26:54.301] Successfully get content of App ID: 1500060
# [2025-05-03 21:26:54.571] Successfully get content of App ID: 1565600
# [2025-05-03 21:26:54.816] Successfully get content of App ID: 1565601
# [2025-05-03 21:26:55.095] Successfully get content of App ID: 1565602
# [2025-05-03 21:26:55.411] Successfully get content of App ID: 3269540
# [2025-05-03 21:26:56.000] Successfully get content of App ID: 910250
# [2025-05-03 21:26:56.694] Successfully get content of App ID: 1565610
# [2025-05-03 21:26:56.952] Successfully get content of App ID: 1500080
# [2025-05-03 21:26:57.213] Successfully get content of App ID: 910260
# [2025-05-03 21:26:57.456] Successfully get content of App ID: 3269560
# [2025-05-03 21:26:57.719] Successfully get content of App ID: 1565630
# [2025-05-03 21:26:58.034] Successfully get content of App ID: 3269570
# [2025-05-03 21:26:58.328] Successfully get content of App ID: 1500100
# [2025-05-03 21:26:58.628] Successfully get content of App ID: 910280
# [2025-05-03 21:26:59.003] Successfully get content of App ID: 1500110
# [2025-05-03 21:26:59.582] Successfully get content of App ID: 910290
# [2025-05-03 21:26:59.990] Successfully get content of App ID: 1565650
# [2025-05-03 21:27:00.574] Successfully get content of App ID: 1500120
# [2025-05-03 21:27:01.715] Successfully get content of App ID: 1565660
# [2025-05-03 21:27:01.968] Successfully get content of App ID: 3269600
# [2025-05-03 21:27:02.347] Successfully get content of App ID: 1500130
# [2025-05-03 21:27:02.660] Successfully get content of App ID: 3269610
# [2025-05-03 21:27:02.906] Successfully get content of App ID: 910320
# [2025-05-03 21:27:03.287] Successfully get content of App ID: 1565680
# [2025-05-03 21:27:03.580] Successfully get content of App ID: 3269620
# [2025-05-03 21:27:04.001] Successfully get content of App ID: 3269630
# [2025-05-03 21:27:04.377] Successfully get content of App ID: 3269640
# [2025-05-03 21:27:04.657] Successfully get content of App ID: 1565710
# [2025-05-03 21:27:04.951] Successfully get content of App ID: 3269650
# [2025-05-03 21:27:05.198] Successfully get content of App ID: 1500180
# [2025-05-03 21:27:05.478] Successfully get content of App ID: 1565720
# [2025-05-03 21:27:05.730] Successfully get content of App ID: 910370
# [2025-05-03 21:27:06.111] Successfully get content of App ID: 3269670
# [2025-05-03 21:27:06.433] Successfully get content of App ID: 1500200
# [2025-05-03 21:27:06.731] Successfully get content of App ID: 910380
# [2025-05-03 21:27:06.984] Successfully get content of App ID: 1565740
# [2025-05-03 21:27:07.239] Successfully get content of App ID: 3269680
# [2025-05-03 21:27:07.675] Successfully get content of App ID: 910390
# [2025-05-03 21:27:08.101] Successfully get content of App ID: 1500220
# [2025-05-03 21:27:08.530] Successfully get content of App ID: 910400
# [2025-05-03 21:27:08.793] Successfully get content of App ID: 1565760
# [2025-05-03 21:27:09.017] Successfully get content of App ID: 3269700
# [2025-05-03 21:27:09.321] Successfully get content of App ID: 1500230
# [2025-05-03 21:27:09.803] Successfully get content of App ID: 910410
# [2025-05-03 21:27:10.110] Successfully get content of App ID: 1565770
# [2025-05-03 21:27:10.376] Successfully get content of App ID: 3269710
# [2025-05-03 21:27:10.608] Successfully get content of App ID: 1500240
# [2025-05-03 21:27:10.961] Successfully get content of App ID: 910420
# [2025-05-03 21:27:11.236] Successfully get content of App ID: 1565780
# [2025-05-03 21:27:11.516] Successfully get content of App ID: 3269720
# [2025-05-03 21:27:11.770] Successfully get content of App ID: 1500250
# [2025-05-03 21:27:12.014] Successfully get content of App ID: 910430
# [2025-05-03 21:27:12.270] Successfully get content of App ID: 1565790
# [2025-05-03 21:27:12.520] No successful response. Add App ID: 3269730 to excluded apps list
# [2025-05-03 21:27:12.783] Successfully get content of App ID: 1500260
# [2025-05-03 21:27:13.071] Successfully get content of App ID: 1565800
# [2025-05-03 21:27:13.328] Successfully get content of App ID: 1500270
# [2025-05-03 21:27:13.617] Successfully get content of App ID: 910450
# [2025-05-03 21:27:14.014] Successfully get content of App ID: 1500280
# [2025-05-03 21:27:14.280] Successfully get content of App ID: 910460
# [2025-05-03 21:27:14.614] No successful response. Add App ID: 1565820 to excluded apps list
# [2025-05-03 21:27:14.904] Successfully get content of App ID: 1500290
# [2025-05-03 21:27:15.124] Successfully get content of App ID: 910470
# [2025-05-03 21:27:15.425] Successfully get content of App ID: 1565830
# [2025-05-03 21:27:15.855] Successfully get content of App ID: 1500300
# [2025-05-03 21:27:16.141] Successfully get content of App ID: 1565840
# [2025-05-03 21:27:16.377] Successfully get content of App ID: 1500310
# [2025-05-03 21:27:16.615] Successfully get content of App ID: 910490
# [2025-05-03 21:27:16.869] Successfully get content of App ID: 1565850
# [2025-05-03 21:27:17.153] Successfully get content of App ID: 1500320
# [2025-05-03 21:27:17.416] Successfully get content of App ID: 910500
# [2025-05-03 21:27:17.689] Successfully get content of App ID: 1565860
# [2025-05-03 21:27:18.016] Successfully get content of App ID: 1565870
# [2025-05-03 21:27:18.324] Successfully get content of App ID: 3269810
# [2025-05-03 21:27:18.582] Successfully get content of App ID: 1500340
# [2025-05-03 21:27:18.844] Successfully get content of App ID: 3630260
# [2025-05-03 21:27:19.098] Successfully get content of App ID: 1565880
# [2025-05-03 21:27:19.381] Successfully get content of App ID: 3269820
# [2025-05-03 21:27:19.696] Successfully get content of App ID: 1500350
# [2025-05-03 21:27:20.064] Successfully get content of App ID: 910530
# [2025-05-03 21:27:20.344] Successfully get content of App ID: 1565890
# [2025-05-03 21:27:20.568] No successful response. Add App ID: 1500360 to excluded apps list
# [2025-05-03 21:27:20.807] Successfully get content of App ID: 910540
# [2025-05-03 21:27:21.119] Successfully get content of App ID: 1565900
# [2025-05-03 21:27:21.418] Successfully get content of App ID: 1500370
# [2025-05-03 21:27:21.799] Successfully get content of App ID: 1565910
# [2025-05-03 21:27:22.058] Successfully get content of App ID: 3269850
# [2025-05-03 21:27:22.475] Successfully get content of App ID: 1500380
# [2025-05-03 21:27:22.817] Successfully get content of App ID: 910560
# [2025-05-03 21:27:23.086] Successfully get content of App ID: 1565920
# [2025-05-03 21:27:23.419] Successfully get content of App ID: 1565921
# [2025-05-03 21:27:23.711] Successfully get content of App ID: 1565922
# [2025-05-03 21:27:24.067] Successfully get content of App ID: 3269860
# [2025-05-03 21:27:24.298] Successfully get content of App ID: 1500390
# [2025-05-03 21:27:24.582] Successfully get content of App ID: 1565930
# [2025-05-03 21:27:24.781] No successful response. Add App ID: 3269870 to excluded apps list
# [2025-05-03 21:27:25.040] Successfully get content of App ID: 1500400
# [2025-05-03 21:27:25.342] Successfully get content of App ID: 1565940
# [2025-05-03 21:27:25.582] Successfully get content of App ID: 3269880
# [2025-05-03 21:27:25.975] Successfully get content of App ID: 1500410
# [2025-05-03 21:27:26.277] Successfully get content of App ID: 910590
# [2025-05-03 21:27:26.568] Successfully get content of App ID: 3269890
# [2025-05-03 21:27:26.845] Successfully get content of App ID: 1500420
# [2025-05-03 21:27:27.098] Successfully get content of App ID: 910600
# [2025-05-03 21:27:27.385] Successfully get content of App ID: 1565960
# [2025-05-03 21:27:27.627] Successfully get content of App ID: 3269900
# [2025-05-03 21:27:27.876] Successfully get content of App ID: 1565970
# [2025-05-03 21:27:28.302] Successfully get content of App ID: 3269910
# [2025-05-03 21:27:28.563] Successfully get content of App ID: 910620
# [2025-05-03 21:27:28.782] No successful response. Add App ID: 1565980 to excluded apps list
# [2025-05-03 21:27:29.017] No successful response. Add App ID: 3269920 to excluded apps list
# [2025-05-03 21:27:29.642] Successfully get content of App ID: 910630
# [2025-05-03 21:27:30.001] Successfully get content of App ID: 1565990
# [2025-05-03 21:27:30.229] Successfully get content of App ID: 3269930
# [2025-05-03 21:27:30.581] Successfully get content of App ID: 910640
# [2025-05-03 21:27:31.004] Successfully get content of App ID: 1566000
# [2025-05-03 21:27:31.387] Successfully get content of App ID: 3269940
# [2025-05-03 21:27:31.641] Successfully get content of App ID: 1500470
# [2025-05-03 21:27:31.913] Successfully get content of App ID: 910650
# [2025-05-03 21:27:32.183] Successfully get content of App ID: 3269950
# [2025-05-03 21:27:32.471] Successfully get content of App ID: 1500480
# [2025-05-03 21:27:32.853] Successfully get content of App ID: 910660
# [2025-05-03 21:27:33.105] Successfully get content of App ID: 3269960
# [2025-05-03 21:27:33.383] Successfully get content of App ID: 1500490
# [2025-05-03 21:27:33.690] Successfully get content of App ID: 3269970
# [2025-05-03 21:27:33.994] Successfully get content of App ID: 1500500
# [2025-05-03 21:27:34.319] Successfully get content of App ID: 1566040
# [2025-05-03 21:27:34.676] Successfully get content of App ID: 3269980
# [2025-05-03 21:27:34.934] Successfully get content of App ID: 1566050
# [2025-05-03 21:27:35.191] Successfully get content of App ID: 3269990
# [2025-05-03 21:27:35.442] Successfully get content of App ID: 910700
# [2025-05-03 21:27:35.756] Successfully get content of App ID: 1566060
# [2025-05-03 21:27:36.197] Successfully get content of App ID: 3270000
# [2025-05-03 21:27:36.427] Successfully get content of App ID: 1500530
# [2025-05-03 21:27:36.664] Successfully get content of App ID: 910710
# [2025-05-03 21:27:36.904] Successfully get content of App ID: 910711
# [2025-05-03 21:27:37.141] Successfully get content of App ID: 1566070
# [2025-05-03 21:27:37.384] Successfully get content of App ID: 3270010
# [2025-05-03 21:27:37.677] Successfully get content of App ID: 1500540
# [2025-05-03 21:27:37.908] No successful response. Add App ID: 1566080 to excluded apps list
# [2025-05-03 21:27:38.322] Successfully get content of App ID: 2278790
# [2025-05-03 21:27:38.629] Successfully get content of App ID: 910730
# [2025-05-03 21:27:38.907] Successfully get content of App ID: 1566090
# [2025-05-03 21:27:39.144] Successfully get content of App ID: 3270030
# [2025-05-03 21:27:39.489] Successfully get content of App ID: 1500560
# [2025-05-03 21:27:39.779] Successfully get content of App ID: 910740
# [2025-05-03 21:27:40.031] Successfully get content of App ID: 3270040
# [2025-05-03 21:27:40.301] Successfully get content of App ID: 3712410
# [2025-05-03 21:27:40.570] Successfully get content of App ID: 910750
# [2025-05-03 21:27:40.897] Successfully get content of App ID: 1566110
# [2025-05-03 21:27:41.267] Successfully get content of App ID: 3270050
# [2025-05-03 21:27:41.495] Successfully get content of App ID: 1500580
# [2025-05-03 21:27:41.779] No successful response. Add App ID: 910760 to excluded apps list
# [2025-05-03 21:27:42.077] Successfully get content of App ID: 1566120
# [2025-05-03 21:27:42.345] Successfully get content of App ID: 1500590
# [2025-05-03 21:27:42.608] Successfully get content of App ID: 910770
# [2025-05-03 21:27:42.875] Successfully get content of App ID: 1500600
# [2025-05-03 21:27:43.155] Successfully get content of App ID: 1566140
# [2025-05-03 21:27:43.434] Successfully get content of App ID: 1566150
# [2025-05-03 21:27:43.729] Successfully get content of App ID: 3270090
# [2025-05-03 21:27:44.004] Successfully get content of App ID: 1500620
# [2025-05-03 21:27:44.305] Successfully get content of App ID: 910800
# [2025-05-03 21:27:44.572] Successfully get content of App ID: 1566160
# [2025-05-03 21:27:44.873] Successfully get content of App ID: 1500630
# [2025-05-03 21:27:45.110] Successfully get content of App ID: 2229720
# [2025-05-03 21:27:45.367] No successful response. Add App ID: 1566170 to excluded apps list
# [2025-05-03 21:27:45.638] Successfully get content of App ID: 3270110
# [2025-05-03 21:27:46.291] Successfully get content of App ID: 910820
# [2025-05-03 21:27:46.754] Successfully get content of App ID: 910821
# [2025-05-03 21:27:47.025] Successfully get content of App ID: 1566180
# [2025-05-03 21:27:47.254] Successfully get content of App ID: 3270120
# [2025-05-03 21:27:47.516] Successfully get content of App ID: 1500650
# [2025-05-03 21:27:47.741] Successfully get content of App ID: 3704300
# [2025-05-03 21:27:48.018] Successfully get content of App ID: 910830
# [2025-05-03 21:27:48.237] Successfully get content of App ID: 1566190
# [2025-05-03 21:27:48.457] Successfully get content of App ID: 3270130
# [2025-05-03 21:27:49.992] Successfully get content of App ID: 1500660
# [2025-05-03 21:27:50.250] Successfully get content of App ID: 1500670
# [2025-05-03 21:27:50.483] Successfully get content of App ID: 1500671
# [2025-05-03 21:27:50.869] Successfully get content of App ID: 1500672
# [2025-05-03 21:27:51.112] Successfully get content of App ID: 1500673
# [2025-05-03 21:27:51.338] Successfully get content of App ID: 910850
# [2025-05-03 21:27:51.692] Successfully get content of App ID: 3270150
# [2025-05-03 21:27:51.925] Successfully get content of App ID: 1500680
# [2025-05-03 21:27:52.228] Successfully get content of App ID: 1566220
# [2025-05-03 21:27:52.513] Successfully get content of App ID: 3270160
# [2025-05-03 21:27:52.752] Successfully get content of App ID: 1500690
# [2025-05-03 21:27:53.011] Successfully get content of App ID: 1566230
# [2025-05-03 21:27:53.252] Too many requests. Put App ID 1500700 back to deque. Sleep for 10 sec
# [2025-05-03 21:28:03.504] Too many requests. Put App ID 1500700 back to deque. Sleep for 10 sec
# [2025-05-03 21:28:13.726] Too many requests. Put App ID 1500700 back to deque. Sleep for 10 sec
# [2025-05-03 21:28:24.012] Too many requests. Put App ID 1500700 back to deque. Sleep for 10 sec
# [2025-05-03 21:28:34.257] Too many requests. Put App ID 1500700 back to deque. Sleep for 10 sec
# [2025-05-03 21:28:44.670] Too many requests. Put App ID 1500700 back to deque. Sleep for 10 sec
# [2025-05-03 21:28:54.912] Too many requests. Put App ID 1500700 back to deque. Sleep for 10 sec
# [2025-05-03 21:29:05.165] Too many requests. Put App ID 1500700 back to deque. Sleep for 10 sec
# [2025-05-03 21:29:15.705] Too many requests. Put App ID 1500700 back to deque. Sleep for 10 sec
# [2025-05-03 21:29:26.097] Too many requests. Put App ID 1500700 back to deque. Sleep for 10 sec
# [2025-05-03 21:29:36.296] Too many requests. Put App ID 1500700 back to deque. Sleep for 10 sec
# [2025-05-03 21:29:46.610] Too many requests. Put App ID 1500700 back to deque. Sleep for 10 sec
# [2025-05-03 21:29:56.897] Too many requests. Put App ID 1500700 back to deque. Sleep for 10 sec
# [2025-05-03 21:30:07.211] Too many requests. Put App ID 1500700 back to deque. Sleep for 10 sec
# [2025-05-03 21:30:17.411] Too many requests. Put App ID 1500700 back to deque. Sleep for 10 sec
# [2025-05-03 21:30:27.768] Too many requests. Put App ID 1500700 back to deque. Sleep for 10 sec
# [2025-05-03 21:30:38.068] Too many requests. Put App ID 1500700 back to deque. Sleep for 10 sec
# [2025-05-03 21:30:48.345] Too many requests. Put App ID 1500700 back to deque. Sleep for 10 sec
# [2025-05-03 21:30:58.637] Too many requests. Put App ID 1500700 back to deque. Sleep for 10 sec
# [2025-05-03 21:31:08.913] Too many requests. Put App ID 1500700 back to deque. Sleep for 10 sec
# [2025-05-03 21:31:19.129] Too many requests. Put App ID 1500700 back to deque. Sleep for 10 sec
# [2025-05-03 21:31:29.557] Too many requests. Put App ID 1500700 back to deque. Sleep for 10 sec
# [2025-05-03 21:31:39.773] Too many requests. Put App ID 1500700 back to deque. Sleep for 10 sec
# [2025-05-03 21:31:50.114] Successfully get content of App ID: 1500700
# [2025-05-03 21:31:50.390] Successfully get content of App ID: 910880
# [2025-05-03 21:31:50.646] Successfully get content of App ID: 2483750
# [2025-05-03 21:31:50.926] Successfully get content of App ID: 1500710
# [2025-05-03 21:31:51.159] Successfully get content of App ID: 1566250
# [2025-05-03 21:31:51.394] No successful response. Add App ID: 3270190 to excluded apps list
# [2025-05-03 21:31:51.641] Successfully get content of App ID: 2483760
# [2025-05-03 21:31:51.963] Successfully get content of App ID: 1566260
# [2025-05-03 21:31:52.289] No successful response. Add App ID: 3270200 to excluded apps list
# [2025-05-03 21:31:52.597] Successfully get content of App ID: 2483770
# [2025-05-03 21:31:53.001] Successfully get content of App ID: 1500730
# [2025-05-03 21:31:53.279] Successfully get content of App ID: 3270210
# [2025-05-03 21:31:53.696] Successfully get content of App ID: 2483780
# [2025-05-03 21:31:54.054] Successfully get content of App ID: 1500740
# [2025-05-03 21:31:54.301] Successfully get content of App ID: 3270220
# [2025-05-03 21:31:54.652] Successfully get content of App ID: 1500750
# [2025-05-03 21:31:54.935] Successfully get content of App ID: 2229840
# [2025-05-03 21:31:55.407] Successfully get content of App ID: 910930
# [2025-05-03 21:31:55.751] Successfully get content of App ID: 910931
# [2025-05-03 21:31:56.017] Successfully get content of App ID: 910932
# [2025-05-03 21:31:56.399] Successfully get content of App ID: 1566290
# [2025-05-03 21:31:56.754] Successfully get content of App ID: 3270230
# [2025-05-03 21:31:57.035] Successfully get content of App ID: 2238040
# [2025-05-03 21:31:57.307] Successfully get content of App ID: 1500760
# [2025-05-03 21:31:57.606] Successfully get content of App ID: 910940
# [2025-05-03 21:31:57.880] Successfully get content of App ID: 3270240
# [2025-05-03 21:31:58.201] Successfully get content of App ID: 1500770
# [2025-05-03 21:31:58.432] Successfully get content of App ID: 1500780
# [2025-05-03 21:31:58.721] Successfully get content of App ID: 1566320
# [2025-05-03 21:31:58.975] Successfully get content of App ID: 3270270
# [2025-05-03 21:31:59.308] Successfully get content of App ID: 2483840
# [2025-05-03 21:31:59.563] Successfully get content of App ID: 1500800
# [2025-05-03 21:31:59.851] Successfully get content of App ID: 910980
# [2025-05-03 21:32:00.132] Successfully get content of App ID: 1566340
# [2025-05-03 21:32:00.425] No successful response. Add App ID: 3270280 to excluded apps list
# [2025-05-03 21:32:00.697] Successfully get content of App ID: 1500810
# [2025-05-03 21:32:00.935] Successfully get content of App ID: 910990
# [2025-05-03 21:32:01.242] Successfully get content of App ID: 1566350
# [2025-05-03 21:32:01.504] Successfully get content of App ID: 1500820
# [2025-05-03 21:32:01.753] Successfully get content of App ID: 911000
# [2025-05-03 21:32:01.975] Successfully get content of App ID: 1566360
# [2025-05-03 21:32:02.246] No successful response. Add App ID: 2483870 to excluded apps list
# [2025-05-03 21:32:02.561] Successfully get content of App ID: 911010
# [2025-05-03 21:32:02.904] Successfully get content of App ID: 1566370
# [2025-05-03 21:32:03.167] Successfully get content of App ID: 3270310
# [2025-05-03 21:32:03.410] Successfully get content of App ID: 2483880
# [2025-05-03 21:32:03.660] Successfully get content of App ID: 1500840
# [2025-05-03 21:32:04.024] No successful response. Add App ID: 911020 to excluded apps list
# [2025-05-03 21:32:04.321] Successfully get content of App ID: 1566380
# [2025-05-03 21:32:04.561] Successfully get content of App ID: 3270320
# [2025-05-03 21:32:04.826] Successfully get content of App ID: 1500850
# [2025-05-03 21:32:05.094] Successfully get content of App ID: 3622580
# [2025-05-03 21:32:05.463] Successfully get content of App ID: 1566390
# [2025-05-03 21:32:05.767] Successfully get content of App ID: 3270330
# [2025-05-03 21:32:06.190] Successfully get content of App ID: 2483900
# [2025-05-03 21:32:06.511] Successfully get content of App ID: 1500860
# [2025-05-03 21:32:06.798] Successfully get content of App ID: 911040
# [2025-05-03 21:32:07.085] Successfully get content of App ID: 1500870
# [2025-05-03 21:32:07.353] Successfully get content of App ID: 911050
# [2025-05-03 21:32:07.637] Successfully get content of App ID: 1566410
# [2025-05-03 21:32:07.862] Successfully get content of App ID: 3606220
# [2025-05-03 21:32:08.103] Successfully get content of App ID: 2483920
# [2025-05-03 21:32:08.408] Successfully get content of App ID: 1500880
# [2025-05-03 21:32:08.733] Successfully get content of App ID: 1566420
# [2025-05-03 21:32:09.074] Successfully get content of App ID: 3270360
# [2025-05-03 21:32:09.456] Successfully get content of App ID: 2483930
# [2025-05-03 21:32:09.782] Successfully get content of App ID: 911070
# [2025-05-03 21:32:10.088] Successfully get content of App ID: 1566430
# [2025-05-03 21:32:10.392] No successful response. Add App ID: 2483940 to excluded apps list
# [2025-05-03 21:32:10.679] Successfully get content of App ID: 1500900
# [2025-05-03 21:32:10.940] Successfully get content of App ID: 911080
# [2025-05-03 21:32:11.205] Successfully get content of App ID: 1566440
# [2025-05-03 21:32:11.452] Successfully get content of App ID: 2483950
# [2025-05-03 21:32:11.753] Successfully get content of App ID: 1500910
# [2025-05-03 21:32:12.061] Successfully get content of App ID: 1566450
# [2025-05-03 21:32:12.812] Successfully get content of App ID: 3270390
# [2025-05-03 21:32:13.722] Successfully get content of App ID: 2483960
# [2025-05-03 21:32:14.042] Successfully get content of App ID: 911100
# [2025-05-03 21:32:14.552] Successfully get content of App ID: 1566460
# [2025-05-03 21:32:14.954] Successfully get content of App ID: 3270400
# [2025-05-03 21:32:15.342] Successfully get content of App ID: 2483970
# [2025-05-03 21:32:15.644] Successfully get content of App ID: 1566470
# [2025-05-03 21:32:15.908] Successfully get content of App ID: 3270410
# [2025-05-03 21:32:16.318] Successfully get content of App ID: 2483980
# [2025-05-03 21:32:16.648] Successfully get content of App ID: 1500940
# [2025-05-03 21:32:16.968] Successfully get content of App ID: 911120
# [2025-05-03 21:32:17.214] Successfully get content of App ID: 1500950
# [2025-05-03 21:32:17.600] Successfully get content of App ID: 911130
# [2025-05-03 21:32:17.868] Successfully get content of App ID: 1566490
# [2025-05-03 21:32:18.136] Successfully get content of App ID: 2484000
# [2025-05-03 21:32:18.446] Successfully get content of App ID: 1500960
# [2025-05-03 21:32:18.700] Successfully get content of App ID: 1566500
# [2025-05-03 21:32:18.971] Successfully get content of App ID: 3270440
# [2025-05-03 21:32:19.294] Successfully get content of App ID: 1500970
# [2025-05-03 21:32:19.646] Successfully get content of App ID: 1566510
# [2025-05-03 21:32:19.954] Successfully get content of App ID: 1500980
# [2025-05-03 21:32:20.223] Successfully get content of App ID: 1566520
# [2025-05-03 21:32:20.548] Successfully get content of App ID: 3270460
# [2025-05-03 21:32:20.882] No successful response. Add App ID: 1500990 to excluded apps list
# [2025-05-03 21:32:21.128] Successfully get content of App ID: 911170
# [2025-05-03 21:32:21.345] Successfully get content of App ID: 1566530
# [2025-05-03 21:32:21.589] Successfully get content of App ID: 3270470
# [2025-05-03 21:32:21.839] Successfully get content of App ID: 911180
# [2025-05-03 21:32:22.112] Successfully get content of App ID: 1566540
# [2025-05-03 21:32:23.098] Successfully get content of App ID: 1501010
# [2025-05-03 21:32:23.862] Successfully get content of App ID: 1566550
# [2025-05-03 21:32:24.459] Successfully get content of App ID: 3606360
# [2025-05-03 21:32:24.835] Successfully get content of App ID: 911200
# [2025-05-03 21:32:25.085] Successfully get content of App ID: 1566560
# [2025-05-03 21:32:25.385] Successfully get content of App ID: 911210
# [2025-05-03 21:32:25.613] Successfully get content of App ID: 1566570
# [2025-05-03 21:32:25.916] Successfully get content of App ID: 3270510
# [2025-05-03 21:32:26.182] Successfully get content of App ID: 1566580
# [2025-05-03 21:32:26.419] Successfully get content of App ID: 3270520
# [2025-05-03 21:32:26.690] Successfully get content of App ID: 911230
# [2025-05-03 21:32:26.908] Successfully get content of App ID: 3270530
# [2025-05-03 21:32:27.263] Successfully get content of App ID: 1501060
# [2025-05-03 21:32:27.509] Successfully get content of App ID: 911240
# [2025-05-03 21:32:27.773] Successfully get content of App ID: 3270540
# [2025-05-03 21:32:28.098] Successfully get content of App ID: 1501070
# [2025-05-03 21:32:28.411] Successfully get content of App ID: 911250
# [2025-05-03 21:32:28.701] Successfully get content of App ID: 1566610
# [2025-05-03 21:32:29.057] Successfully get content of App ID: 3270550
# [2025-05-03 21:32:29.387] Successfully get content of App ID: 1501080
# [2025-05-03 21:32:29.675] Successfully get content of App ID: 1501081
# [2025-05-03 21:32:29.982] Successfully get content of App ID: 1501082
# [2025-05-03 21:32:30.301] Successfully get content of App ID: 1566620
# [2025-05-03 21:32:30.692] Successfully get content of App ID: 3270560
# [2025-05-03 21:32:31.031] Successfully get content of App ID: 911270
# [2025-05-03 21:32:31.323] Successfully get content of App ID: 3270570
# [2025-05-03 21:32:31.760] Successfully get content of App ID: 1501100
# [2025-05-03 21:32:32.905] Successfully get content of App ID: 911280
# [2025-05-03 21:32:33.187] Successfully get content of App ID: 3270580
# [2025-05-03 21:32:33.434] Successfully get content of App ID: 1501110
# [2025-05-03 21:32:33.682] Successfully get content of App ID: 911290
# [2025-05-03 21:32:34.029] No successful response. Add App ID: 1566650 to excluded apps list
# [2025-05-03 21:32:34.362] Successfully get content of App ID: 1501120
# [2025-05-03 21:32:34.590] Successfully get content of App ID: 1566660
# [2025-05-03 21:32:34.842] Successfully get content of App ID: 3270600
# [2025-05-03 21:32:35.185] Successfully get content of App ID: 1501130
# [2025-05-03 21:32:35.477] Successfully get content of App ID: 911310
# [2025-05-03 21:32:35.749] Successfully get content of App ID: 1566670
# [2025-05-03 21:32:36.057] Successfully get content of App ID: 3270610
# [2025-05-03 21:32:36.431] Successfully get content of App ID: 1501140
# [2025-05-03 21:32:36.666] Successfully get content of App ID: 911320
# [2025-05-03 21:32:37.099] Successfully get content of App ID: 1566680
# [2025-05-03 21:32:37.371] Successfully get content of App ID: 3270620
# [2025-05-03 21:32:37.640] Successfully get content of App ID: 1501150
# [2025-05-03 21:32:37.862] Successfully get content of App ID: 1566690
# [2025-05-03 21:32:38.223] Successfully get content of App ID: 3270630
# [2025-05-03 21:32:38.528] Successfully get content of App ID: 1501160
# [2025-05-03 21:32:38.760] Successfully get content of App ID: 1566700
# [2025-05-03 21:32:39.032] Successfully get content of App ID: 3270640
# [2025-05-03 21:32:39.259] No successful response. Add App ID: 1501170 to excluded apps list
# [2025-05-03 21:32:39.499] Successfully get content of App ID: 1566710
# [2025-05-03 21:32:39.698] Successfully get content of App ID: 3270650
# [2025-05-03 21:32:39.931] Successfully get content of App ID: 1501180
# [2025-05-03 21:32:40.178] Successfully get content of App ID: 3270660
# [2025-05-03 21:32:40.440] Successfully get content of App ID: 1501190
# [2025-05-03 21:32:40.688] Successfully get content of App ID: 1566730
# [2025-05-03 21:32:40.984] No successful response. Add App ID: 3270670 to excluded apps list
# [2025-05-03 21:32:41.236] Successfully get content of App ID: 911380
# [2025-05-03 21:32:41.485] Successfully get content of App ID: 1566740
# [2025-05-03 21:32:41.821] Successfully get content of App ID: 3270680
# [2025-05-03 21:32:42.362] Successfully get content of App ID: 2484250
# [2025-05-03 21:32:42.647] Successfully get content of App ID: 1501210
# [2025-05-03 21:32:42.836] Successfully get content of App ID: 1566750
# [2025-05-03 21:32:43.088] Successfully get content of App ID: 2484260
# [2025-05-03 21:32:43.359] Successfully get content of App ID: 1501220
# [2025-05-03 21:32:43.678] Successfully get content of App ID: 911400
# [2025-05-03 21:32:43.988] No successful response. Add App ID: 1566760 to excluded apps list
# [2025-05-03 21:32:44.201] Successfully get content of App ID: 3270700
# [2025-05-03 21:32:44.428] Successfully get content of App ID: 2484270
# [2025-05-03 21:32:44.680] Successfully get content of App ID: 911410
# [2025-05-03 21:32:44.951] Successfully get content of App ID: 1566770
# [2025-05-03 21:32:45.206] Successfully get content of App ID: 3270710
# [2025-05-03 21:32:45.434] Successfully get content of App ID: 2484280
# [2025-05-03 21:32:45.633] No successful response. Add App ID: 1501240 to excluded apps list
# [2025-05-03 21:32:45.854] No successful response. Add App ID: 1501241 to excluded apps list
# [2025-05-03 21:32:46.205] No successful response. Add App ID: 1501242 to excluded apps list
# [2025-05-03 21:32:46.457] Successfully get content of App ID: 911420
# [2025-05-03 21:32:46.773] No successful response. Add App ID: 1501243 to excluded apps list
# [2025-05-03 21:32:46.956] No successful response. Add App ID: 1501244 to excluded apps list
# [2025-05-03 21:32:47.161] No successful response. Add App ID: 1501245 to excluded apps list
# [2025-05-03 21:32:47.425] No successful response. Add App ID: 1501246 to excluded apps list
# [2025-05-03 21:32:47.597] No successful response. Add App ID: 1501247 to excluded apps list
# [2025-05-03 21:32:47.843] No successful response. Add App ID: 1501248 to excluded apps list
# [2025-05-03 21:32:48.018] No successful response. Add App ID: 1501249 to excluded apps list
# [2025-05-03 21:32:48.243] No successful response. Add App ID: 1501250 to excluded apps list
# [2025-05-03 21:32:48.423] No successful response. Add App ID: 1501251 to excluded apps list
# [2025-05-03 21:32:48.930] Successfully get content of App ID: 911430
# [2025-05-03 21:32:49.340] No successful response. Add App ID: 1501252 to excluded apps list
# [2025-05-03 21:32:50.103] No successful response. Add App ID: 1501253 to excluded apps list
# [2025-05-03 21:32:50.274] No successful response. Add App ID: 1501254 to excluded apps list
# ...
# [2025-05-03 22:28:06.488] Successfully get content of App ID: 1498530
# [2025-05-03 22:28:06.680] Successfully get content of App ID: 3702180
# [2025-05-03 22:28:06.922] Successfully get content of App ID: 916900
# [2025-05-03 22:28:07.114] Successfully get content of App ID: 1572260
# [2025-05-03 22:28:07.332] Successfully get content of App ID: 3276200
# [2025-05-03 22:28:07.524] Successfully get content of App ID: 2489770
# [2025-05-03 22:28:07.796] Successfully get content of App ID: 1498540
# [2025-05-03 22:28:07.987] Successfully get content of App ID: 916910
# [2025-05-03 22:28:08.254] Successfully get content of App ID: 1572270
# [2025-05-03 22:28:08.439] Successfully get content of App ID: 3276210
# [2025-05-03 22:28:08.684] Successfully get content of App ID: 916920
# [2025-05-03 22:28:08.885] Successfully get content of App ID: 1572280
# [2025-05-03 22:28:09.095] Successfully get content of App ID: 3276220
# [2025-05-03 22:28:09.275] Successfully get content of App ID: 916930
# [2025-05-03 22:28:09.472] Successfully get content of App ID: 3276230
# [2025-05-03 22:28:09.697] Successfully get content of App ID: 2489800
# [2025-05-03 22:28:09.940] Successfully get content of App ID: 1498570
# [2025-05-03 22:28:10.141] Successfully get content of App ID: 3702220
# [2025-05-03 22:28:10.345] Successfully get content of App ID: 2489810
# [2025-05-03 22:28:10.686] Successfully get content of App ID: 1498580
# [2025-05-03 22:28:10.883] Successfully get content of App ID: 916950
# [2025-05-03 22:28:11.087] Successfully get content of App ID: 1498590
# [2025-05-03 22:28:11.289] Successfully get content of App ID: 916960
# [2025-05-03 22:28:11.518] Successfully get content of App ID: 1572320
# [2025-05-03 22:28:11.711] Successfully get content of App ID: 3276260
# [2025-05-03 22:28:11.915] Successfully get content of App ID: 1498600
# [2025-05-03 22:28:12.139] Successfully get content of App ID: 916970
# [2025-05-03 22:28:12.385] Successfully get content of App ID: 1572330
# [2025-05-03 22:28:12.678] Successfully get content of App ID: 2489840
# [2025-05-03 22:28:13.054] No successful response. Add App ID: 1498610 to excluded apps list
# [2025-05-03 22:28:13.544] Successfully get content of App ID: 2489850
# [2025-05-03 22:28:14.251] Successfully get content of App ID: 2489860
# [2025-05-03 22:28:14.451] Successfully get content of App ID: 1498630
# [2025-05-03 22:28:14.652] Successfully get content of App ID: 917000
# [2025-05-03 22:28:14.907] Successfully get content of App ID: 917010
# [2025-05-03 22:28:15.118] Successfully get content of App ID: 917011
# [2025-05-03 22:28:15.324] Successfully get content of App ID: 917012
# [2025-05-03 22:28:15.509] Successfully get content of App ID: 917013
# [2025-05-03 22:28:15.739] Successfully get content of App ID: 3276310
# [2025-05-03 22:28:16.013] Successfully get content of App ID: 917014
# [2025-05-03 22:28:16.229] Successfully get content of App ID: 2489880
# [2025-05-03 22:28:16.433] Successfully get content of App ID: 917015
# [2025-05-03 22:28:16.652] Successfully get content of App ID: 917016
# [2025-05-03 22:28:16.851] Successfully get content of App ID: 917017
# [2025-05-03 22:28:17.036] Successfully get content of App ID: 917018
# [2025-05-03 22:28:17.227] Successfully get content of App ID: 917019
# [2025-05-03 22:28:17.427] Successfully get content of App ID: 917020
# [2025-05-03 22:28:17.608] Successfully get content of App ID: 1572380
# [2025-05-03 22:28:17.789] No successful response. Add App ID: 3276320 to excluded apps list
# [2025-05-03 22:28:17.979] Successfully get content of App ID: 1498660
# [2025-05-03 22:28:18.211] Successfully get content of App ID: 917030
# [2025-05-03 22:28:18.430] Successfully get content of App ID: 917031
# [2025-05-03 22:28:18.632] Successfully get content of App ID: 917032
# [2025-05-03 22:28:18.991] Successfully get content of App ID: 917033
# [2025-05-03 22:28:19.205] Successfully get content of App ID: 2489900
# [2025-05-03 22:28:19.396] Successfully get content of App ID: 917040
# [2025-05-03 22:28:19.610] Successfully get content of App ID: 3276340
# [2025-05-03 22:28:19.813] Successfully get content of App ID: 1498680
# [2025-05-03 22:28:20.034] Successfully get content of App ID: 917050
# [2025-05-03 22:28:20.250] No successful response. Add App ID: 1572410 to excluded apps list
# [2025-05-03 22:28:20.436] Successfully get content of App ID: 3276350
# [2025-05-03 22:28:20.790] Successfully get content of App ID: 3677760
# [2025-05-03 22:28:21.000] Successfully get content of App ID: 1498690
# [2025-05-03 22:28:21.227] Successfully get content of App ID: 1572420
# [2025-05-03 22:28:21.431] Successfully get content of App ID: 3276360
# [2025-05-03 22:28:21.629] Successfully get content of App ID: 2489930
# [2025-05-03 22:28:21.863] Successfully get content of App ID: 1990220
# [2025-05-03 22:28:22.098] Successfully get content of App ID: 3276370
# [2025-05-03 22:28:22.297] Successfully get content of App ID: 1498710
# [2025-05-03 22:28:22.588] Successfully get content of App ID: 917080
# [2025-05-03 22:28:23.084] No successful response. Add App ID: 3276380 to excluded apps list
# [2025-05-03 22:28:23.503] Successfully get content of App ID: 2489950
# [2025-05-03 22:28:24.228] Successfully get content of App ID: 1498720
# [2025-05-03 22:28:24.457] Successfully get content of App ID: 917090
# [2025-05-03 22:28:24.671] Successfully get content of App ID: 1572450
# [2025-05-03 22:28:24.868] Successfully get content of App ID: 2489960
# [2025-05-03 22:28:25.068] Successfully get content of App ID: 1572460
# [2025-05-03 22:28:25.290] Successfully get content of App ID: 3276400
# [2025-05-03 22:28:25.487] Successfully get content of App ID: 2489970
# [2025-05-03 22:28:25.686] Successfully get content of App ID: 1498740
# [2025-05-03 22:28:25.926] Successfully get content of App ID: 917110
# [2025-05-03 22:28:26.140] Successfully get content of App ID: 1572470
# [2025-05-03 22:28:26.427] Successfully get content of App ID: 3276410
# [2025-05-03 22:28:26.649] Successfully get content of App ID: 1498750
# [2025-05-03 22:28:26.902] Successfully get content of App ID: 1572480
# [2025-05-03 22:28:27.209] Successfully get content of App ID: 2489990
# [2025-05-03 22:28:27.429] Successfully get content of App ID: 1498760
# [2025-05-03 22:28:27.636] Successfully get content of App ID: 917130
# [2025-05-03 22:28:27.832] Successfully get content of App ID: 1572490
# [2025-05-03 22:28:28.184] Successfully get content of App ID: 1572491
# [2025-05-03 22:28:28.386] Successfully get content of App ID: 3276430
# [2025-05-03 22:28:28.568] Successfully get content of App ID: 1498770
# [2025-05-03 22:28:28.849] Successfully get content of App ID: 917140
# [2025-05-03 22:28:29.102] Successfully get content of App ID: 1572500
# [2025-05-03 22:28:29.324] Successfully get content of App ID: 3276440
# [2025-05-03 22:28:29.511] Successfully get content of App ID: 3702430
# [2025-05-03 22:28:29.760] Successfully get content of App ID: 917150
# [2025-05-03 22:28:29.957] Successfully get content of App ID: 3276450
# [2025-05-03 22:28:30.187] Successfully get content of App ID: 2490020
# [2025-05-03 22:28:30.403] Successfully get content of App ID: 1498790
# [2025-05-03 22:28:30.646] Successfully get content of App ID: 3276460
# [2025-05-03 22:28:30.849] Successfully get content of App ID: 2490030
# [2025-05-03 22:28:31.074] Successfully get content of App ID: 1498800
# [2025-05-03 22:28:31.339] Successfully get content of App ID: 1498801
# [2025-05-03 22:28:31.637] Successfully get content of App ID: 917170
# [2025-05-03 22:28:31.828] Successfully get content of App ID: 3276470
# [2025-05-03 22:28:32.069] Successfully get content of App ID: 2490040
# [2025-05-03 22:28:32.274] Successfully get content of App ID: 2490050
# [2025-05-03 22:28:32.435] Too many requests. Put App ID 1498820 back to deque. Sleep for 10 sec
# [2025-05-03 22:28:42.599] Too many requests. Put App ID 1498820 back to deque. Sleep for 10 sec
# [2025-05-03 22:28:52.802] Too many requests. Put App ID 1498820 back to deque. Sleep for 10 sec
# [2025-05-03 22:29:03.602] Too many requests. Put App ID 1498820 back to deque. Sleep for 10 sec
# [2025-05-03 22:29:13.794] Too many requests. Put App ID 1498820 back to deque. Sleep for 10 sec
# [2025-05-03 22:29:24.083] Too many requests. Put App ID 1498820 back to deque. Sleep for 10 sec
# [2025-05-03 22:29:34.282] Too many requests. Put App ID 1498820 back to deque. Sleep for 10 sec
# [2025-05-03 22:29:44.485] Too many requests. Put App ID 1498820 back to deque. Sleep for 10 sec
# [2025-05-03 22:29:54.957] Too many requests. Put App ID 1498820 back to deque. Sleep for 10 sec
# [2025-05-03 22:30:05.555] Too many requests. Put App ID 1498820 back to deque. Sleep for 10 sec
# [2025-05-03 22:30:15.779] Too many requests. Put App ID 1498820 back to deque. Sleep for 10 sec
# [2025-05-03 22:30:25.953] Too many requests. Put App ID 1498820 back to deque. Sleep for 10 sec
# [2025-05-03 22:30:36.155] Too many requests. Put App ID 1498820 back to deque. Sleep for 10 sec
# [2025-05-03 22:30:46.365] Too many requests. Put App ID 1498820 back to deque. Sleep for 10 sec
# [2025-05-03 22:30:56.667] Too many requests. Put App ID 1498820 back to deque. Sleep for 10 sec
# [2025-05-03 22:31:06.858] Too many requests. Put App ID 1498820 back to deque. Sleep for 10 sec
# [2025-05-03 22:31:17.047] Too many requests. Put App ID 1498820 back to deque. Sleep for 10 sec
# [2025-05-03 22:31:27.243] Too many requests. Put App ID 1498820 back to deque. Sleep for 10 sec
# [2025-05-03 22:31:37.463] Too many requests. Put App ID 1498820 back to deque. Sleep for 10 sec
# [2025-05-03 22:31:47.735] Too many requests. Put App ID 1498820 back to deque. Sleep for 10 sec
# [2025-05-03 22:31:57.956] Too many requests. Put App ID 1498820 back to deque. Sleep for 10 sec
# [2025-05-03 22:32:08.174] Too many requests. Put App ID 1498820 back to deque. Sleep for 10 sec
# [2025-05-03 22:32:18.371] Too many requests. Put App ID 1498820 back to deque. Sleep for 10 sec
# [2025-05-03 22:32:28.543] Too many requests. Put App ID 1498820 back to deque. Sleep for 10 sec
# [2025-05-03 22:32:38.778] Successfully get content of App ID: 1498820
# [2025-05-03 22:32:39.139] Successfully get content of App ID: 917190
# [2025-05-03 22:32:39.330] Successfully get content of App ID: 3276490
# [2025-05-03 22:32:39.516] Successfully get content of App ID: 2490060
# [2025-05-03 22:32:39.715] Successfully get content of App ID: 1498830
# [2025-05-03 22:32:39.935] Successfully get content of App ID: 3702480
# [2025-05-03 22:32:40.174] Successfully get content of App ID: 917200
# [2025-05-03 22:32:40.404] Successfully get content of App ID: 3276500
# [2025-05-03 22:32:40.641] Successfully get content of App ID: 1498840
# [2025-05-03 22:32:40.804] No successful response. Add App ID: 917210 to excluded apps list
# [2025-05-03 22:32:41.016] Successfully get content of App ID: 3276510
# [2025-05-03 22:32:41.207] Successfully get content of App ID: 2490080
# [2025-05-03 22:32:41.406] Successfully get content of App ID: 1498850
# [2025-05-03 22:32:41.610] Successfully get content of App ID: 917220
# [2025-05-03 22:32:41.807] Successfully get content of App ID: 3276520
# [2025-05-03 22:32:42.009] Successfully get content of App ID: 2490090
# [2025-05-03 22:32:42.196] Successfully get content of App ID: 3276530
# [2025-05-03 22:32:42.419] Successfully get content of App ID: 2490100
# [2025-05-03 22:32:42.637] Successfully get content of App ID: 917240
# [2025-05-03 22:32:42.885] Successfully get content of App ID: 3276540
# [2025-05-03 22:32:43.076] No successful response. Add App ID: 1498880 to excluded apps list
# [2025-05-03 22:32:43.306] Successfully get content of App ID: 917250
# [2025-05-03 22:32:43.541] Successfully get content of App ID: 3276550
# [2025-05-03 22:32:43.743] Successfully get content of App ID: 917260
# [2025-05-03 22:32:43.977] Successfully get content of App ID: 3276560
# [2025-05-03 22:32:44.173] Successfully get content of App ID: 2490130
# [2025-05-03 22:32:44.411] Successfully get content of App ID: 1498900
# [2025-05-03 22:32:44.615] Successfully get content of App ID: 3276570
# [2025-05-03 22:32:44.826] Successfully get content of App ID: 2490140
# [2025-05-03 22:32:45.016] Successfully get content of App ID: 917280
# [2025-05-03 22:32:45.213] Successfully get content of App ID: 1498920
# [2025-05-03 22:32:45.460] Successfully get content of App ID: 917290
# [2025-05-03 22:32:45.668] Successfully get content of App ID: 3276590
# [2025-05-03 22:32:45.875] Successfully get content of App ID: 2490160
# [2025-05-03 22:32:46.069] Successfully get content of App ID: 3276600
# [2025-05-03 22:32:46.260] Successfully get content of App ID: 2490170
# [2025-05-03 22:32:46.473] Successfully get content of App ID: 1498940
# [2025-05-03 22:32:46.677] Successfully get content of App ID: 2219850
# [2025-05-03 22:32:46.878] Successfully get content of App ID: 2490190
# [2025-05-03 22:32:47.043] No successful response. Add App ID: 3276630 to excluded apps list
# [2025-05-03 22:32:47.272] Successfully get content of App ID: 2490200
# [2025-05-03 22:32:47.482] Successfully get content of App ID: 3465050
# [2025-05-03 22:32:47.677] Successfully get content of App ID: 2490210
# [2025-05-03 22:32:47.890] Successfully get content of App ID: 1498980
# [2025-05-03 22:32:48.078] Successfully get content of App ID: 2490220
# [2025-05-03 22:32:48.275] Successfully get content of App ID: 3637100
# [2025-05-03 22:32:48.478] Successfully get content of App ID: 1498990
# [2025-05-03 22:32:48.671] Successfully get content of App ID: 3276660
# [2025-05-03 22:32:48.862] Successfully get content of App ID: 3276670
# [2025-05-03 22:32:49.202] Successfully get content of App ID: 2490240
# [2025-05-03 22:32:49.390] Successfully get content of App ID: 1499010
# [2025-05-03 22:32:49.611] Successfully get content of App ID: 917380
# [2025-05-03 22:32:49.822] Successfully get content of App ID: 3276680
# [2025-05-03 22:32:50.011] Successfully get content of App ID: 2490250
# [2025-05-03 22:32:50.213] Successfully get content of App ID: 917390
# [2025-05-03 22:32:50.886] Successfully get content of App ID: 2490260
# [2025-05-03 22:32:51.755] Successfully get content of App ID: 1499030
# [2025-05-03 22:32:51.961] Successfully get content of App ID: 2490270
# [2025-05-03 22:32:52.145] Successfully get content of App ID: 1499040
# [2025-05-03 22:32:52.350] Successfully get content of App ID: 1499060
# [2025-05-03 22:32:52.539] Successfully get content of App ID: 1572790
# [2025-05-03 22:32:52.806] Successfully get content of App ID: 3276730
# [2025-05-03 22:32:53.008] Successfully get content of App ID: 2490300
# [2025-05-03 22:32:53.260] Successfully get content of App ID: 1572800
# [2025-05-03 22:32:53.467] Successfully get content of App ID: 2490310
# [2025-05-03 22:32:53.705] Successfully get content of App ID: 1572810
# [2025-05-03 22:32:53.936] Successfully get content of App ID: 1572820
# [2025-05-03 22:32:54.118] Successfully get content of App ID: 3276760
# [2025-05-03 22:32:54.390] Successfully get content of App ID: 2490330
# [2025-05-03 22:32:54.613] Successfully get content of App ID: 1499100
# [2025-05-03 22:32:54.886] Successfully get content of App ID: 1572830
# [2025-05-03 22:32:55.082] Successfully get content of App ID: 3276780
# [2025-05-03 22:32:55.315] Successfully get content of App ID: 3391470
# [2025-05-03 22:32:55.525] Successfully get content of App ID: 1499120
# [2025-05-03 22:32:55.711] Successfully get content of App ID: 1572850
# [2025-05-03 22:32:55.923] Successfully get content of App ID: 3276790
# [2025-05-03 22:33:00.920] Successfully create app_dict checkpoint: C:\Users\azure\Documents\CS122\project\checkpoints\apps_dict-ckpt-fin.p
# [2025-05-03 22:33:00.921] Successfully create excluded apps checkpoint: C:\Users\azure\Documents\CS122\project\checkpoints\excluded_apps_list-ckpt-fin.p
# [2025-05-03 22:33:00.922] Successfully create error apps checkpoint: C:\Users\azure\Documents\CS122\project\checkpoints\error_apps_list-ckpt-fin.p
#
# [2025-05-03 22:33:00.922] Total number of valid apps: 126692
# [2025-05-03 22:33:00.922] Total number of skipped apps: 113819
# [2025-05-03 22:33:00.922] Total number of error apps: 145
# [2025-05-03 22:33:00.922] Successful run. Program Terminates.
